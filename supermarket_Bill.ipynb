# %%
from datetime import datetime

# %%
name = input("Enter your name:")

#List of items
lists =  '''
Rice    Rs 20/kg
Suger   Rs 30/kg
Salt    Rs 20/kg
oil     Rs 80/liter
paneer  Rs 110/kg
Maggi   Rs 50/kg
Boost   Rs 90/each
Colgate Rs  85/each
'''
# Declaration
price = 0
pricelist = []
totalprice = 0
finalprice= 0
ilist = []
qlist = []
plist = []

#rates for items
items = {'rice':20,
         'suger':30,
         'salt':20,
         'oil':80,
         'panner':110,
         'maggi':50,
         'boost':90,
         'colgate':85}

option = int(input("For list of items press 1 : "))
if option == 1:
    print(lists)

for i in range(len(items)):
    inp1 = int(input("If you want to buy press 1 or 2 for exit: "))
    if inp1 == 2:
        break
    if inp1 == 1:
        item=input("Enter your items : ")
        quantity = int(input("Enter quantity : "))
        if item in items.keys():
            price = quantity*(items[item])
            pricelist.append((item,quantity,items,price))
            totalprice += price
            ilist.append(item)
            qlist.append(quantity)
            plist.append(price)
            gst = (totalprice*5)/100
            finalamount = gst+totalprice
        else:
            print("Sorry you entered item is not avaliable")
    else:
        print("You have entered a wrong option")
    inp = input("Can I bill the items yes or no : ")
    if inp == 'yes':
        pass
        if finalamount != 0:
            print(25*"=","Kiran supermarket",25*"=")
            print(28*"=","Hyderabad",28*"=")
            print("name : ",name,30*" ",'Date : ',datetime.now())
            print(75*"=")
            print('Sno',8*" ",'Items',8*" ",'Quantity',20*" ","Price")
            for i in range(len(pricelist)):
                print(i,8*" ",1*" ",ilist[i],13*" ",qlist[i],25*" ",plist[i])
            print(75*"_")
            print(50*" ",'TotalAmount : ', 'Rs',totalprice)
            print('GSTAmount',55*" ", 'Rs',gst)
            print(50*" ",'TotalAmount : ','Rs',finalamount)
            print(75*"_")
            print(25*" ",'Thanks for visiting')
            print(75*"_")
# Out:
# Enter your name:taruni
# For list of items press 1 : 1
#
# Rice    Rs 20/kg
# Suger   Rs 30/kg
# Salt    Rs 20/kg
# oil     Rs 80/liter
# paneer  Rs 110/kg
# Maggi   Rs 50/kg
# Boost   Rs 90/each
# Colgate Rs  85/each
#
# If you want to buy press 1 or 2 for exit: 1
# Enter your items : rice
# Enter quantity : 3
# Can I bill the items yes or no : yes
# ========================= Kiran supermarket =========================
# ============================ Hyderabad ============================
# name :  taruni                                Date :  2023-07-31 21:49:58.212557
# ...
# Sno          Items          Quantity                      Price
# 0            rice               3                           60
# ___________________________________________________________________________
#                                                    TotalAmount :  Rs 60
# GSTAmount                                                         Rs 3.0
# ...
